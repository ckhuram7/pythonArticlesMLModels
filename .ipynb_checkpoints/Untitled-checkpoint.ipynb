# %% [markdown]
# # Data Exploration

# %% [raw]
# #########################################################################
# # Khuram Chughtai
# # Web Mining Class
# # Exploring all-the-news Dataset
# # https://www.kaggle.com/snapcrack/all-the-news/version/4#_=_
# # 143,000 Articles from 15 different publications

# %%
# Magics Command to display Matplotlib charts in the notebook itself
# %matplotlib inline

# Importing in Libraries to help with Data Exploration
import matplotlib
import pandas
import numpy
import matplotlib.pyplot as plotter

# %%
articlesDF1 = pandas.read_csv("dataSetOriginal/articles1.csv", index_col=False)
#articlesDF2 = pandas.read_csv("dataSetOriginal/articles2.csv", index_col=False)
#articlesDF3 = pandas.read_csv("dataSetOriginal/articles3.csv", index_col=False)

# %%
articlesDF1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
# Unnamed: 0     50000 non-null int64
# id             50000 non-null int64
# title          50000 non-null object
# publication    50000 non-null object
# author         43694 non-null object
# date           50000 non-null object
# year           50000 non-null float64
# month          50000 non-null float64
# url            0 non-null float64
# content        50000 non-null object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 2.9+ MB

# %%
articlesDF1.plot()
